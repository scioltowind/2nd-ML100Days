# %% [markdown]
# 作業1：
# 1. 你選的這組資料為何重要
#     https://www.kaggle.com/ankkur13/boston-crime-data
#     選擇Crimes in Boston" ，因為犯罪資料分析可以由歸納方式找出犯罪熱點(包含地點、時間)，對於公共利益及公共安全有影響性。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#      提供者為 Boston Police Department。
#
# 3. 蒐集而來的資料型態為何
#       是屬於結構化資料，檔案類型為：csv，
#       內容的資料型態包含string, real, time, int
#
# 4. 這組資料想解決的問題如何評估
#      什麼時間、地點與犯罪類型的分析→   迴歸分析
#      犯罪類型是否與區域性有相關→  Accuray

# %% [markdown]
# 作業2
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 	提升業績是車隊經營的核心問題，因此包含了：
#           一、提升載客量，什麼時間、地點。可以獲得較多的客群。
#           二、非尖峰時間，如何減少空車時間。
#           三、車程、車資及油資關係。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#    資料從何而來：
#         經濟部取得定期發布的油價資料。
#         交通部取得即時發布的路況資料。
#         由車隊自行搜集載客資料，上、下車地點、時間、性別等。
#
# 3. 蒐集而來的資料型態為何
# 	 屬結構化資料，但是要依各單位資料結構檢視 欄位意義。
#      資料型態應會包含 real、int、string、time
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#       什麼樣的地點、時間會有較高的載客率。→ Accuray
#       在什麼時間及地點上車的客人，其單趟所獲得的收益是具高效益的。→ 迴歸分析(MSE)

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_h):
    #計算取得平方差(MSE)
    mse  = sum((y - y_h)**2)/len(y)
    return mse 

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 208.087
# The Mean absolute error is 11.347
